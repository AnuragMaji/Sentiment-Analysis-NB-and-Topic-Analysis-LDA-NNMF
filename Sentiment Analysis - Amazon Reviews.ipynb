# %% [markdown]
# ### Method 1 : Naive Bayes Classifer for Sentiment Analysis

# %%
import pandas

import numpy

from nltk.corpus import stopwords

import nltk

from nltk.tokenize import RegexpTokenizer

from nltk.classify import NaiveBayesClassifier

import nltk.classify.util, nltk.metrics

from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english", ignore_stopwords=True)

import random

# %%
#Reading data

data = pandas.read_csv("Amazon_Unlocked_Mobile_iphone6.csv", encoding='utf-8')

data = data[['Reviews','Rating']]

# %%
#polarity assignment

data['polarity'] = numpy.where(data['Rating']>3, 'pos', 'neg')

data['Reviews'] = data['Reviews'].str.lower()

# %%
#creating word feature_extraction

def create_word_features(para):

    tokenizer = RegexpTokenizer(r'\w+')

    words = tokenizer.tokenize(para)

    useful_words = [word for word in words if word not in nltk.corpus.stopwords.words("english")]

    base_words = [stemmer.stem(word) for word in useful_words]

    my_dict = dict([(word, True) for word in base_words])

    return my_dict

# %%
#Stratified sampling

data_pos= data.loc[(data['polarity'] == 'pos')]

data_neg = data.loc[(data['polarity'] == 'neg')]

data_neg = data_neg.dropna()

data_pos = data_pos.dropna()

# %%
pos_reviews = []

for i in data_pos['Reviews']:

    pos_reviews.append((create_word_features(i), "positive"))

print(len(pos_reviews))

pos_reviews
# Out:
# 3724
# [({'6': True,
#    'appl': True,
#    'call': True,
#    'card': True,
#    'contact': True,
#    'could': True,
#    'discov': True,
#    'easili': True,
#    'everyth': True,
#    'expect': True,
#    'good': True,
#    'hesit': True,
#    'iphon': True,
#    'like': True,
#    'new': True,
#    'phone': True,
#    'purchas': True,
#    'recommend': True,
#    'regist': True,
#    'repres': True,
#    'seller': True,
#    'sim': True,
#    'sinc': True,
#    'unlock': True,
#    'verizon': True,
#    'would': True},
#   'positive'),
#  ({'4': True,
#    '6': True,
#    'appear': True,
#    'awesom': True,
#    'believ': True,
#    'camera': True,
#    'clear': True,
#    'crystal': True,
#    'differ': True,
#    'far': True,
#    'fast': True,
#    'final': True,
#    'freez': True,
#    'gold': True,
#    'huge': True,
#    'iphon': True,
#    'last': True,
#    'long': True,
#    'market': True,
#    'phone': True,
#    'processor': True,
#    'qualiti': True,
#    'superior': True,
#    'time': True,
#    'upgrad': True},
#   'positive'),
#  ({'16gb': True,
#    '6': True,
#    'advertis': True,
#    'box': True,
#    'case': True,
#    'come': True,
#    'disappoint': True,
#    'free': True,
#    'iphon': True,
#    'origin': True,
#    'silver': True,
#    'though': True},
#   'positive'),
#  ({'articl': True,
#    'came': True,
#    'consid': True,
#    'day': True,
#    'deliv': True,
#    'deliveri': True,
#    'everyth': True,
#    'fine': True,
#    'got': True,
#    'holiday': True,
#    'like': True,
#    'new': True,
#    'nice': True,
#    'phone': True,
#    'promis': True,
#    'suppos': True,
#    'two': True,
#    'well': True,
#    'work': True,
#    'wrap': True},
#   'positive'),
#  ({'complain': True, 'exact': True, 'expect': True}, 'positive'),
#  ({'arriv': True, 'expect': True, 'great': True, 'work': True}, 'positive'),
#  ({'100': True, 'good': True}, 'positive'),
#  ({'awesom': True, 'phone': True}, 'positive'),
#  ({'excel': True, 'phone': True}, 'positive'),
#  ({'easili': True,
#    'exact': True,
#    'perfect': True,
#    'product': True,
#    'set': True,
#    'suppos': True,
#    'work': True},
#   'positive'),
#  ({'featur': True, 'love': True, 'new': True, 'right': True, 'size': True},
#   'positive'),
#  ({'could': True,
#    'everyth': True,
#    'grey': True,
#    'love': True,
#    'one': True,
#    'perfect': True,
#    'tho': True,
#    'trade': True,
#    'wish': True,
#    'world': True},
#   'positive'),
#  ({'far': True, 'good': True}, 'positive'),
#  ({'came': True,
#    'condit': True,
#    'crack': True,
#    'good': True,
#    'got': True,
#    'scratch': True,
#    'turn': True,
#    'yet': True},
#   'positive'),
#  ({'son': True, 'want': True}, 'positive'),
#  ({'perfect': True, 'phone': True}, 'positive'),
#  ({'condition1': True,
#    'new': True,
#    'origin': True,
#    'perfect': True,
#    'version': True},
#   'positive'),
#  ({'nice': True}, 'positive'),
#  ({'expect': True}, 'positive'),
#  ({'2': True,
#    'advertis': True,
#    'ago': True,
#    'beauti': True,
#    'bit': True,
#    'comput': True,
#    'condit': True,
#    'even': True,
#    'first': True,
#    'freak': True,
#    'got': True,
#    'issu': True,
#    'like': True,
#    'littl': True,
#    'new': True,
#    'phone': True,
#    'plug': True,
#    'problem': True,
#    'quick': True,
#    'scratch': True,
#    'screen': True,
#    'sinc': True,
#    'singl': True,
#    'super': True,
#    'week': True,
#    'work': True},
#   'positive'),
#  ({'beauti': True}, 'positive'),
#  ({'excel': True, 'thank': True}, 'positive'),
#  ({'advertis': True,
#    'code': True,
#    'could': True,
#    'email': True,
#    'great': True,
#    'look': True,
#    'pass': True,
#    'password': True,
#    'phone': True,
#    'protect': True,
#    'receiv': True,
#    'use': True,
#    'work': True},
#   'positive'),
#  ({'thank': True}, 'positive'),
#  ({'expect': True, 'pleas': True}, 'positive'),
#  ({'fine': True, 'good': True, 'perfect': True, 'pretti': True, 'work': True},
#   'positive'),
#  ({'2': True,
#    'atleast': True,
#    'iphon': True,
#    'love': True,
#    'month': True,
#    'phone': True,
#    'problem': True},
#   'positive'),
#  ({'good': True}, 'positive'),
#  ({'great': True, 'nice': True, 'phone': True}, 'positive'),
#  ({'sweet': True}, 'positive'),
#  ({'great': True}, 'positive'),
#  ({'good': True}, 'positive'),
#  ({'good': True}, 'positive'),
#  ({'grade': True, 'need': True, 'one': True, 'phone': True}, 'positive'),
#  ({'good': True, 'price': True, 'qualiti': True, 'use': True}, 'positive'),
#  ({'good': True}, 'positive'),
#  ({'nun': True}, 'positive'),
#  ({'expect': True}, 'positive'),
#  ({'app': True,
#    'appl': True,
#    'awesom': True,
#    'back': True,
#    'camera': True,
#    'design': True,
#    'favorit': True,
#    'fit': True,
#    'front': True,
#    'great': True,
#    'hand': True,
#    'left': True,
#    'love': True,
#    'mani': True,
#    'memori': True,
#    'overal': True,
#    'perfect': True,
#    'phone': True,
#    'pictur': True,
#    'plenti': True,
#    'product': True,
#    'qualiti': True,
#    'sleek': True,
#    'song': True,
#    'storag': True,
#    'thousand': True,
#    'use': True,
#    'year': True,
#    'yet': True},
#   'positive'),
#  ({'3': True,
#    '3g': True,
#    '5s': True,
#    '6': True,
#    '90': True,
#    'actual': True,
#    'admit': True,
#    'allow': True,
#    'amaz': True,
#    'angl': True,
#    'app': True,
#    'becom': True,
#    'bigger': True,
#    'book': True,
#    'buy': True,
#    'certain': True,
#    'choic': True,
#    'clear': True,
#    'compar': True,
#    'crystal': True,
#    'cutout': True,
#    'day': True,
#    'decis': True,
#    'dimens': True,
#    'durat': True,
#    'edg': True,
#    'email': True,
#    'end': True,
#    'especi': True,
#    'even': True,
#    'everi': True,
#    'everyth': True,
#    'exact': True,
#    'excel': True,
#    'excit': True,
#    'extra': True,
#    'extrem': True,
#    'facebook': True,
#    'far': True,
#    'feel': True,
#    'first': True,
#    'flaw': True,
#    'follow': True,
#    'found': True,
#    'galaxi': True,
#    'get': True,
#    'go': True,
#    'gorgeous': True,
#    'great': True,
#    'hand': True,
#    'hard': True,
#    'help': True,
#    'hold': True,
#    'honest': True,
#    'hope': True,
#    'imagin': True,
#    'immedi': True,
#    'increas': True,
#    'iphon': True,
#    'landscap': True,
#    'launch': True,
#    'learn': True,
#    'light': True,
#    'like': True,
#    'longer': True,
#    'look': True,
#    'lot': True,
#    'lucki': True,
#    'make': True,
#    'massiv': True,
#    'mess': True,
#    'mode': True,
#    'model': True,
#    'movi': True,
#    'much': True,
#    'must': True,
#    'note': True,
#    'older': True,
#    'one': True,
#    'order': True,
#    'own': True,
#    'paper': True,
#    'past': True,
#    'phone': True,
#    'plus': True,
#    'pre': True,
#    'quit': True,
#    'read': True,
#    'releas': True,
#    'rough': True,
#    'screen': True,
#    'similar': True,
#    'sinc': True,
#    'size': True,
#    'smooth': True,
#    'store': True,
#    'surf': True,
#    'text': True,
#    'thing': True,
#    'think': True,
#    'three': True,
#    'torn': True,
#    'two': True,
#    'uncomfort': True,
#    'unless': True,
#    'use': True,
#    'version': True,
#    'watch': True,
#    'web': True,
#    'week': True,
#    'went': True,
#    'wife': True,
#    'without': True},
#   'positive'),
#  ({'describ': True,
#    'happi': True,
#    'like': True,
#    'new': True,
#    'phone': True,
#    'use': True},
#   'positive'),
#  ({'easi': True, 'pretti': True, 'use': True}, 'positive'),
#  ({'absolut': True,
#    'buy': True,
#    'definit': True,
#    'perfect': True,
#    'product': True,
#    'worth': True},
#   'positive'),
#  ({'bravo': True}, 'positive'),
#  ({'amaz': True,
#    'buy': True,
#    'definit': True,
#    'devic': True,
#    'new': True,
#    'phone': True,
#    'seller': True,
#    'would': True},
#   'positive'),
#  ({'4': True,
#    'color': True,
#    'everi': True,
#    'gave': True,
#    'gold': True,
#    'got': True,
#    'order': True,
#    'place': True,
#    'reason': True,
#    'silver': True,
#    'star': True,
#    'thing': True},
#   'positive'),
#  ({'love': True}, 'positive'),
#  ({'recomendado': True}, 'positive'),
#  ({'flawless': True, 'great': True, 'phone': True, 'product': True},
#   'positive'),
#  ({'4': True,
#    'abl': True,
#    'almost': True,
#    'alreadi': True,
#    'also': True,
#    'bet': True,
#    'bottom': True,
#    'box': True,
#    'buy': True,
#    'came': True,
#    'charger': True,
#    'convert': True,
#    'corner': True,
#    'differ': True,
#    'dink': True,
#    'earbud': True,
#    'els': True,
#    'everyth': True,
#    'exact': True,
#    'first': True,
#    'freak': True,
#    'gave': True,
#    'got': True,
#    'one': True,
#    'order': True,
#    'perfect': True,
#    'phone': True,
#    'pictur': True,
#    'plan': True,
#    'problem': True,
#    'provid': True,
#    'put': True,
#    'said': True,
#    'show': True,
#    'star': True,
#    'take': True,
#    'thing': True,
#    'took': True,
#    'total': True,
#    'unlock': True,
#    'vari': True,
#    'verizon': True,
#    'want': True},
#   'positive'),
#  ({'love': True, 'phone': True, 'wife': True}, 'positive'),
#  ({'definit': True, 'price': True, 'worth': True}, 'positive'),
#  ({'condit': True,
#    'daughter': True,
#    'get': True,
#    'issu': True,
#    'mobil': True,
#    'perfect': True,
#    'phone': True,
#    'purchas': True,
#    'servic': True,
#    'troubl': True},
#   'positive'),
#  ({'nice': True}, 'positive'),
#  ({'noth': True}, 'positive'),
#  ({'charm': True,
#    'condit': True,
#    'descript': True,
#    'great': True,
#    'like': True,
#    'look': True,
#    'meet': True,
#    'minor': True,
#    'mint': True,
#    'phone': True,
#    'scratch': True,
#    'still': True,
#    'work': True},
#   'positive'),
#  ({'expect': True, 'love': True, 'phone': True, 'way': True}, 'positive'),
#  ({'love': True}, 'positive'),
#  ({'back': True,
#    'better': True,
#    'button': True,
#    'expect': True,
#    'fail': True,
#    'fix': True,
#    'good': True,
#    'great': True,
#    'home': True,
#    'issu': True,
#    'know': True,
#    'look': True,
#    'mention': True,
#    'phone': True,
#    'product': True,
#    'seller': True,
#    'send': True,
#    'touch': True,
#    'work': True},
#   'positive'),
#  ({'good': True}, 'positive'),
#  ({'camera': True, 'volum': True, 'work': True}, 'positive'),
#  ({'better': True,
#    'expect': True,
#    'love': True,
#    'perfect': True,
#    'phone': True,
#    'son': True},
#   'positive'),
#  ({'perfect': True}, 'positive'),
#  ({'perfect': True, 'work': True}, 'positive'),
#  ({'accessori': True,
#    'brand': True,
#    'everi': True,
#    'full': True,
#    'new': True,
#    'ok': True,
#    'origin': True,
#    'phone': True,
#    'thank': True,
#    'thing': True,
#    'unlock': True},
#   'positive'),
#  ({'giftperfect': True, 'nice': True}, 'positive'),
#  ({'far': True, 'got': True, 'like': True, 'wife': True}, 'positive'),
#  ({'great': True, 'happi': True, 'phone': True, 'purchas': True}, 'positive'),
#  ({'accur': True, 'great': True, 'phone': True, 'seller': True}, 'positive'),
#  ({'good': True, 'great': True, 'phone': True, 'price': True}, 'positive'),
#  ({'carrier': True,
#    'deliveri': True,
#    'differ': True,
#    'great': True,
#    'phone': True,
#    'price': True,
#    'request': True,
#    'use': True,
#    'usp': True,
#    'would': True},
#   'positive'),
#  ({'far': True, 'ok': True, 'phone': True, 'problem': True}, 'positive'),
#  ({'love': True}, 'positive'),
#  ({'data': True, 'happi': True, 'phone': True, 'plan': True, 'unlimit': True},
#   'positive'),
#  ({'better': True, 'expect': True, 'phone': True}, 'positive'),
#  ({'5c': True,
#    'appl': True,
#    'big': True,
#    'bigger': True,
#    'decis': True,
#    'disappoint': True,
#    'favorit': True,
#    'id': True,
#    'love': True,
#    'phone': True,
#    'plus': True,
#    'product': True,
#    'sever': True,
#    'size': True,
#    'touch': True,
#    'upgrad': True,
#    'year': True},
#   'positive'),
#  ({'6': True, 'daughter': True, 'iphon': True, 'love': True}, 'positive'),
#  ({'love': True, 'thank': True}, 'positive'),
#  ({'great': True, 'issu': True, 'phone': True, 'thank': True, 'work': True},
#   'positive'),
#  ({'avail': True,
#    'beauti': True,
#    'bill': True,
#    'half': True,
#    'instrument': True,
#    'never': True,
#    'new': True,
#    'pay': True,
#    'phone': True,
#    'price': True,
#    'product': True,
#    'purchas': True,
#    'refurbish': True,
#    'servic': True,
#    'sign': True,
#    'thank': True,
#    'use': True},
#   'positive'),
#  ({'correct': True,
#    'describ': True,
#    'email': True,
#    'exact': True,
#    'notifi': True,
#    'number': True,
#    'perfect': True,
#    'phone': True,
#    'prompt': True,
#    'quick': True,
#    'repli': True,
#    'return': True,
#    'ship': True,
#    'track': True,
#    'work': True},
#   'positive'),
#  ({'acn': True,
#    'activ': True,
#    'condit': True,
#    'coupl': True,
#    'day': True,
#    'flash': True,
#    'glad': True,
#    'great': True,
#    'like': True,
#    'network': True,
#    'new': True,
#    'perfect': True,
#    'phone': True,
#    'purchas': True,
#    'valu': True,
#    'verizon': True,
#    'work': True},
#   'positive'),
#  ({'ad': True,
#    'buy': True,
#    'great': True,
#    'look': True,
#    'new': True,
#    'phone': True,
#    'problem': True,
#    'servic': True},
#   'positive'),
#  ({'6': True, 'awesom': True, 'iphon': True}, 'positive'),
#  ({'awesom': True}, 'positive'),
#  ({'adequ': True,
#    'basic': True,
#    'microphon': True,
#    'otherwis': True,
#    'siri': True,
#    'talk': True,
#    'text': True,
#    'voic': True,
#    'work': True},
#   'positive'),
#  ({'condit': True,
#    'good': True,
#    'physic': True,
#    'pretti': True,
#    'well': True,
#    'work': True},
#   'positive'),
#  ({'perfect': True, 'work': True}, 'positive'),
#  ({'happi': True}, 'positive'),
#  ({'great': True}, 'positive'),
#  ({'bought': True,
#    'brand': True,
#    'condit': True,
#    'function': True,
#    'great': True,
#    'like': True,
#    'new': True,
#    'well': True},
#   'positive'),
#  ({'deal': True, 'good': True, 'great': True, 'product': True}, 'positive'),
#  ({'anoth': True,
#    'came': True,
#    'charg': True,
#    'day': True,
#    'descript': True,
#    'earlier': True,
#    'eta': True,
#    'everyth': True,
#    'glitch': True,
#    'plus': True,
#    'right': True,
#    'spot': True,
#    'zero': True},
#   'positive'),
#  ({'happi': True, 'love': True, 'phone': True, 'purchas': True}, 'positive'),
#  ({'came': True,
#    'great': True,
#    'happi': True,
#    'like': True,
#    'look': True,
#    'money': True,
#    'never': True,
#    'phone': True,
#    'purchas': True,
#    'shape': True,
#    'son': True,
#    'thus': True,
#    'use': True,
#    'well': True,
#    'worth': True},
#   'positive'),
#  ({'64gb': True,
#    'almost': True,
#    'batteri': True,
#    'bought': True,
#    'caveat': True,
#    'center': True,
#    'charg': True,
#    'constant': True,
#    'cover': True,
#    'entertain': True,
#    'excel': True,
#    'extern': True,
#    'factor': True,
#    'import': True,
#    'life': True,
#    'main': True,
#    'memori': True,
#    'phone': True,
#    'product': True,
#    'robust': True,
#    'second': True,
#    'travel': True},
#   'positive'),
#  ({'describ': True}, 'positive'),
#  ({'aaaaaaaaaaa': True}, 'positive'),
#  ({'deliveri': True,
#    'fast': True,
#    'good': True,
#    'product': True,
#    'thank': True},
#   'positive'),
#  ({'bad': True, 'phone': True}, 'positive'),
#  ({'good': True,
#    'great': True,
#    'ipon': True,
#    'last': True,
#    'otherwis': True,
#    'satisfi': True,
#    'volum': True},
#   'positive'),
#  ({'advertis': True,
#    'appl': True,
#    'arriv': True,
#    'charger': True,
#    'even': True,
#    'good': True,
#    'headphon': True,
#    'origin': True,
#    'packag': True,
#    'ship': True,
#    'sticker': True,
#    'timeiphon': True},
#   'positive'),
#  ({'excel': True, 'plus': True, 'product': True, 'seller': True}, 'positive'),
#  ({'6': True,
#    'amazon': True,
#    'bought': True,
#    'good': True,
#    'iphon': True,
#    'satisfi': True,
#    'tnx': True,
#    'work': True},
#   'positive'),
#  ({'bought': True,
#    'love': True,
#    'pleas': True,
#    'son': True,
#    'well': True,
#    'youngest': True},
#   'positive'),
#  ({'satisfi': True}, 'positive'),
#  ({'arriv': True,
#    'condit': True,
#    'earli': True,
#    'exact': True,
#    'extrem': True,
#    'happi': True,
#    'price': True,
#    'product': True,
#    'promis': True},
#   'positive'),
#  ({'exact': True, 'said': True}, 'positive'),
#  ({'actual': True,
#    'buy': True,
#    'condit': True,
#    'devic': True,
#    'electron': True,
#    'first': True,
#    'good': True,
#    'hard': True,
#    'lot': True,
#    'love': True,
#    'money': True,
#    'never': True,
#    'onlin': True,
#    'pay': True,
#    'phone': True,
#    'purchas': True,
#    'recommend': True,
#    'seen': True,
#    'someth': True,
#    'special': True,
#    'use': True,
#    'worri': True},
#   'positive'),
#  ({'awesom': True, 'ðÿ': True}, 'positive'),
#  ({'great': True, 'love': True, 'unit': True}, 'positive'),
#  ({'describ': True, 'happi': True, 'phone': True}, 'positive'),
#  ({'phone': True, 'wdll': True, 'work': True}, 'positive'),
#  ({'capabl': True, 'great': True, 'lot': True, 'phone': True}, 'positive'),
#  ({'64gb': True,
#    'app': True,
#    'awesom': True,
#    'buy': True,
#    'came': True,
#    'condit': True,
#    'ect': True,
#    'flawless': True,
#    'glad': True,
#    'got': True,
#    'great': True,
#    'lot': True,
#    'pic': True,
#    'price': True,
#    'storag': True,
#    'vid': True,
#    'well': True,
#    'work': True},
#   'positive'),
#  ({'arriv': True,
#    'brand': True,
#    'iphon': True,
#    'new': True,
#    'promis': True,
#    'time': True},
#   'positive'),
#  ({'came': True, 'expect': True}, 'positive'),
#  ({'easi': True, 'love': True, 'phone': True, 'use': True}, 'positive'),
#  ({'happi': True, 'iphon': True}, 'positive'),
#  ({'fast': True, 'great': True, 'product': True, 'ship': True}, 'positive'),
#  ({'great': True, 'phone': True}, 'positive'),
#  ({'excel': True,
#    'mark': True,
#    'product': True,
#    'usag': True,
#    'without': True},
#   'positive'),
#  ({'great': True}, 'positive'),
#  ({'great': True}, 'positive'),
#  ({'1g': True,
#    '50': True,
#    'expens': True,
#    'great': True,
#    'iphon': True,
#    'like': True,
#    'love': True,
#    'new': True,
#    'pay': True,
#    'phone': True,
#    'plan': True,
#    'virizen': True,
#    'work': True},
#   'positive'),
#  ({'appl': True,
#    'better': True,
#    'big': True,
#    'could': True,
#    'done': True,
#    'ear': True,
#    'hard': True,
#    'hear': True,
#    'ok': True,
#    'person': True,
#    'phone': True,
#    'piec': True,
#    'signal': True,
#    'sim': True,
#    'suck': True,
#    'talk': True,
#    'time': True},
#   'positive'),
#  ({'hype': True, 'live': True, 'love': True}, 'positive'),
#  ({'3': True,
#    'absolut': True,
#    'brand': True,
#    'day': True,
#    'earlier': True,
#    'expect': True,
#    'far': True,
#    'got': True,
#    'look': True,
#    'love': True,
#    'new': True,
#    'notic': True,
#    'phone': True,
#    'problem': True},
#   'positive'),
#  ({'brand': True,
#    'great': True,
#    'like': True,
#    'new': True,
#    'phone': True,
#    'price': True},
#   'positive'),
#  ({'activ': True,
#    'perfect': True,
#    'price': True,
#    'problem': True,
#    'verizon': True,
#    'work': True},
#   'positive'),
#  ({'good': True}, 'positive'),
#  ({'love': True}, 'positive'),
#  ({'advertis': True, 'everyth': True, 'fast': True, 'ship': True}, 'positive'),
#  ({'cheap': True,
#    'everyth': True,
#    'give': True,
#    'headphon': True,
#    'right': True},
#   'positive'),
#  ({'4s': True,
#    '911': True,
#    'a1549': True,
#    'accept': True,
#    'actual': True,
#    'address': True,
#    'also': True,
#    'alway': True,
#    'anyon': True,
#    'around': True,
#    'ask': True,
#    'awd': True,
#    'bad': True,
#    'bag': True,
#    'basic': True,
#    'batteri': True,
#    'beat': True,
#    'best': True,
#    'better': True,
#    'big': True,
#    'bigger': True,
#    'bit': True,
#    'bought': True,
#    'box': True,
#    'brought': True,
#    'call': True,
#    'capab': True,
#    'card': True,
#    'carri': True,
#    'cdma': True,
#    'chanc': True,
#    'charger': True,
#    'cheaper': True,
#    'complain': True,
#    'complet': True,
#    'condit': True,
#    'confirm': True,
#    'could': True,
#    'custom': True,
#    'deactiv': True,
#    'deal': True,
#    'decid': True,
#    'dent': True,
#    'descript': True,
#    'done': True,
#    'earbud': True,
#    'els': True,
#    'everyth': True,
#    'excel': True,
#    'extra': True,
#    'featur': True,
#    'firmwar': True,
#    'first': True,
#    'fit': True,
#    'fron': True,
#    'get': True,
#    'given': True,
#    'glass': True,
#    'go': True,
#    'good': True,
#    'got': True,
#    'great': True,
#    'gsm': True,
#    'hedg': True,
#    'help': True,
#    'hotspot': True,
#    'includ': True,
#    'inform': True,
#    'iphon': True,
#    'knew': True,
#    'leas': True,
#    'life': True,
#    'like': True,
#    'long': True,
#    'look': True,
#    'love': True,
#    'lowest': True,
#    'mani': True,
#    'mark': True,
#    'match': True,
#    'matter': True,
#    'mayb': True,
#    'mean': True,
#    'mobil': True,
#    'model': True,
#    'modela1549': True,
#    'must': True,
#    'new': True,
#    'noth': True,
#    'notic': True,
#    'okay': True,
#    'one': True,
#    'order': True,
#    'origin': True,
#    'paid': True,
#    'part': True,
#    'person': True,
#    'phone': True,
#    'plastic': True,
#    'plus': True,
#    'pocket': True,
#    'price': True,
#    'put': True,
#    'quit': True,
#    'readi': True,
#    'realli': True,
#    'receiv': True,
#    'return': True,
#    'right': True,
#    'sale': True,
#    'scratch': True,
#    'screen': True,
#    'search': True,
#    'sell': True,
#    'seller': True,
#    'servic': True,
#    'sign': True,
#    'sim': True,
#    'size': True,
#    'slight': True,
#    'someon': True,
#    'state': True,
#    'sure': True,
#    'take': True,
#    'thing': True,
#    'though': True,
#    'threw': True,
#    'time': True,
#    'took': True,
#    'tri': True,
#    'turn': True,
#    'unhappi': True,
#    'unlock': True,
#    'usa': True,
#    'use': True,
#    'verizon': True,
#    'wait': True,
#    'warehous': True,
#    'wear': True,
#    'whoever': True,
#    'wifi': True,
#    'work': True,
#    'worth': True,
#    'would': True},
#   'positive'),
#  ({'complaint': True,
#    'good': True,
#    'product': True,
#    'quick': True,
#    'ship': True},
#   'positive'),
#  ({'absolut': True, 'love': True}, 'positive'),
#  ({'great': True, 'phone': True, 'thank': True}, 'positive'),
#  ({'around': True,
#    'great': True,
#    'high': True,
#    'recommend': True,
#    'seller': True},
#   'positive'),
#  ({'everyth': True, 'good': True, 'tx': True}, 'positive'),
#  ({'far': True, 'first': True, 'great': True, 'iphon': True}, 'positive'),
#  ({'good': True}, 'positive'),
#  ({'descript': True,
#    'exceed': True,
#    'expect': True,
#    'far': True,
#    'product': True},
#   'positive'),
#  ({'came': True,
#    'day': True,
#    'describ': True,
#    'earli': True,
#    'even': True,
#    'exact': True,
#    'item': True,
#    'quick': True,
#    'ship': True,
#    'thank': True,
#    'two': True},
#   'positive'),
#  ({'2': True,
#    '5': True,
#    'day': True,
#    'expect': True,
#    'great': True,
#    'nice': True,
#    'phone': True,
#    'servic': True,
#    'ship': True,
#    'sooner': True,
#    'thank': True},
#   'positive'),
#  ({'great': True, 'went': True}, 'positive'),
#  ({'200': True,
#    '5': True,
#    'ago': True,
#    'bigger': True,
#    'bought': True,
#    'everyon': True,
#    'expect': True,
#    'got': True,
#    'hook': True,
#    'incid': True,
#    'iphon': True,
#    'know': True,
#    'month': True,
#    'network': True,
#    'phone': True,
#    'refurbish': True,
#    'save': True,
#    'sever': True,
#    'sinc': True,
#    'thinner': True,
#    'took': True,
#    'verizon': True,
#    'way': True,
#    'without': True,
#    'work': True},
#   'positive'),
#  ({'activ': True,
#    'brand': True,
#    'charger': True,
#    'describ': True,
#    'earbud': True,
#    'exact': True,
#    'includ': True,
#    'look': True,
#    'new': True,
#    'packag': True,
#    'seal': True,
#    'second': True,
#    'show': True,
#    'thru': True,
#    'time': True,
#    'verizon': True,
#    'well': True,
#    'within': True},
#   'positive'),
#  ({'problem': True}, 'positive'),
#  ({'connect': True, 'great': True, 'phone': True, 'problem': True},
#   'positive'),
#  ({'card': True,
#    'gift': True,
#    'go': True,
#    'great': True,
#    'phone': True,
#    'purchas': True,
#    'sim': True,
#    'verizon': True,
#    'work': True},
#   'positive'),
#  ({'6': True,
#    'good': True,
#    'iphon': True,
#    'love': True,
#    'run': True,
#    'ðÿ': True,
#    'š': True},
#   'positive'),
#  ({'amaz': True}, 'positive'),
#  ({'actual': True,
#    'carrier': True,
#    'case': True,
#    'clean': True,
#    'condit': True,
#    'coupl': True,
#    'current': True,
#    'definit': True,
#    'describ': True,
#    'even': True,
#    'exact': True,
#    'excel': True,
#    'futur': True,
#    'guy': True,
#    'includ': True,
#    'issu': True,
#    'look': True,
#    'near': True,
#    'phone': True,
#    'pinch': True,
#    'prompt': True,
#    'protector': True,
#    'purchas': True,
#    'real': True,
#    'receiv': True,
#    'screen': True,
#    'starter': True,
#    'switch': True,
#    'test': True,
#    'took': True,
#    'use': True,
#    'verizon': True,
#    'wipe': True},
#   'positive'),
#  ({'absolut': True,
#    'appl': True,
#    'awesom': True,
#    'bought': True,
#    'brand': True,
#    'case': True,
#    'charger': True,
#    'direct': True,
#    'happier': True,
#    'like': True,
#    'love': True,
#    'much': True,
#    'new': True,
#    'phone': True,
#    'purchas': True,
#    'receiv': True,
#    'scratch': True,
#    'store': True,
#    'thank': True,
#    'two': True,
#    'went': True},
#   'positive'),
#  ({'great': True, 'phone': True}, 'positive'),
#  ({'anoth': True,
#    'get': True,
#    'help': True,
#    'new': True,
#    'one': True,
#    'phone': True,
#    'want': True},
#   'positive'),
#  ({'far': True,
#    'fast': True,
#    'great': True,
#    'issu': True,
#    'item': True,
#    'order': True,
#    'quick': True,
#    'ship': True,
#    'work': True},
#   'positive'),
#  ({'gift': True, 'phone': True, 'pleas': True, 'purchas': True, 'wife': True},
#   'positive'),
#  ({'carrier': True,
#    'great': True,
#    'love': True,
#    'tracfon': True,
#    'work': True},
#   'positive'),
#  ({'amazon': True,
#    'best': True,
#    'know': True,
#    'long': True,
#    'phone': True,
#    'pick': True,
#    'seller': True,
#    'thank': True,
#    'time': True,
#    'veer': True},
#   'positive'),
#  ({'good': True, 'grandson': True, 'product': True, 'proud': True},
#   'positive'),
#  ({'6': True,
#    'abl': True,
#    'account': True,
#    'activ': True,
#    'ad': True,
#    'also': True,
#    'came': True,
#    'card': True,
#    'come': True,
#    'daughter': True,
#    'get': True,
#    'got': True,
#    'hoop': True,
#    'iphon': True,
#    'jump': True,
#    'like': True,
#    'list': True,
#    'littl': True,
#    'love': True,
#    'mislead': True,
#    'network': True,
#    'phone': True,
#    'product': True,
#    'realli': True,
#    'said': True,
#    'say': True,
#    'sim': True,
#    'sinc': True,
#    'store': True,
#    'though': True,
#    'took': True,
#    'verizon': True,
#    'wireless': True,
#    'work': True,
#    'would': True},
#   'positive'),
#  ({'best': True, 'ever': True, 'iphon': True}, 'positive'),
#  ({'came': True, 'perfect': True, 'phone': True, 'time': True}, 'positive'),
#  ({'advertis': True,
#    'arriv': True,
#    'exact': True,
#    'expect': True,
#    'fine': True,
#    'item': True,
#    'pleas': True,
#    'purchas': True,
#    'time': True,
#    'work': True},
#   'positive'),
#  ({'app': True,
#    'backup': True,
#    'batteri': True,
#    'casene': True,
#    'comparison': True,
#    'dayne': True,
#    'extern': True,
#    'good': True,
#    'last': True,
#    'look': True,
#    'money': True,
#    'monopolistmi': True,
#    'need': True,
#    'old': True,
#    'phone': True,
#    'phonepro': True,
#    'protector': True,
#    'protectorne': True,
#    'screen': True,
#    'sum': True,
#    'work': True,
#    'workscon': True},
#   'positive'),
#  ({'great': True, 'phone': True, 'work': True}, 'positive'),
#  ({'appl': True,
#    'great': True,
#    'high': True,
#    'product': True,
#    'recommend': True},
#   'positive'),
#  ({'brand': True,
#    'came': True,
#    'detail': True,
#    'like': True,
#    'look': True,
#    'new': True,
#    'phone': True,
#    'true': True},
#   'positive'),
#  ({'arriv': True, 'perfect': True, 'quick': True, 'work': True}, 'positive'),
#  ({'best': True, 'deal': True, 'ever': True}, 'positive'),
#  ({'complaint': True,
#    'happi': True,
#    'new': True,
#    'phone': True,
#    'plus': True,
#    'receiv': True,
#    'son': True},
#   'positive'),
#  ({'fast': True,
#    'look': True,
#    'said': True,
#    'ship': True,
#    'thank': True,
#    'work': True},
#   'positive'),
#  ({'brand': True,
#    'cellcow': True,
#    'good': True,
#    'great': True,
#    'help': True,
#    'hope': True,
#    'impress': True,
#    'look': True,
#    'new': True,
#    'noth': True,
#    'product': True,
#    'put': True,
#    'review': True,
#    'say': True,
#    'sim': True,
#    'work': True},
#   'positive'),
#  ({'christma': True,
#    'gift': True,
#    'great': True,
#    'iphon': True,
#    'made': True,
#    'phone': True,
#    'thank': True},
#   'positive'),
#  ({'adjust': True,
#    'amaz': True,
#    'could': True,
#    'especi': True,
#    'ever': True,
#    'everyth': True,
#    'fast': True,
#    'get': True,
#    'hope': True,
#    'phone': True,
#    'pictur': True,
#    'process': True,
#    'qualiti': True,
#    'resolut': True,
#    'screen': True,
#    'size': True,
#    'sleek': True,
#    'slim': True,
#    'smaller': True,
#    'switch': True,
#    'take': True,
#    'time': True,
#    'use': True,
#    'well': True,
#    'worth': True,
#    'would': True},
#   'positive'),
#  ({'ok': True, 'vse': True}, 'positive'),
#  ({'alway': True,
#    'ambit': True,
#    'anyway': True,
#    'appl': True,
#    'better': True,
#    'els': True,
#    'everyth': True,
#    'like': True,
#    'product': True,
#    'qualiti': True,
#    'screen': True,
#    'wider': True,
#    'yes': True},
#   'positive'),
#  ({'appl': True,
#    'easi': True,
#    'hit': True,
#    'hold': True,
#    'iphon': True,
#    'perfect': True,
#    'phone': True,
#    'size': True,
#    'style': True},
#   'positive'),
#  ({'100': True,
#    'buy': True,
#    'comun': True,
#    'discriv': True,
#    'extra': True,
#    'fast': True,
#    'good': True,
#    'ir': True,
#    'item': True,
#    'littl': True,
#    'plus': True,
#    'recomend': True,
#    'seller': True,
#    'ship': True,
#    'would': True},
#   'positive'),
#  ({'buy': True, 'definit': True, 'would': True}, 'positive'),
#  ({'good': True, 'use': True}, 'positive'),
#  ({'great': True,
#    'headphon': True,
#    'isnt': True,
#    'jack': True,
#    'phone': True,
#    'proper': True,
#    'servic': True,
#    'ship': True,
#    'unfortun': True,
#    'work': True},
#   'positive'),
#  ({'great': True}, 'positive'),
#  ({'6': True,
#    'buy': True,
#    'came': True,
#    'card': True,
#    'connect': True,
#    'doubl': True,
#    'enjoy': True,
#    'granddaught': True,
#    'iphon': True,
#    'issu': True,
#    'item': True,
#    'packag': True,
#    'phone': True,
#    'sim': True,
#    'time': True,
#    'verizon': True},
#   'positive'),
#  ({'exact': True, 'love': True, 'want': True}, 'positive'),
#  ({'4': True,
#    'birthday': True,
#    'bought': True,
#    'condit': True,
#    'earli': True,
#    'great': True,
#    'haha': True,
#    'husband': True,
#    'love': True,
#    'present': True,
#    'price': True,
#    'thank': True},
#   'positive'),
#  ({'excel': True}, 'positive'),
#  ({'gotta': True, 'know': True, 'one': True, 'u': True}, 'positive'),
#  ({'everyth': True,
#    'freez': True,
#    'hate': True,
#    'iphon': True,
#    'love': True,
#    'turn': True},
#   'positive'),
#  ({'custom': True, 'great': True, 'phone': True, 'servic': True}, 'positive'),
#  ({'much': True, 'quick': True, 'save': True, 'ship': True}, 'positive'),
#  ({'accessori': True,
#    'arriv': True,
#    'love': True,
#    'phone': True,
#    'quick': True},
#   'positive'),
#  ({'absolut': True,
#    'crack': True,
#    'got': True,
#    'love': True,
#    'quick': True,
#    'scratch': True,
#    'thank': True},
#   'positive'),
#  ({'android': True,
#    'arriv': True,
#    'great': True,
#    'iphon': True,
#    'love': True,
#    'phone': True,
#    'quick': True,
#    'seller': True,
#    'stick': True,
#    'thank': True,
#    'window': True},
#   'positive'),
#  ({'condit': True,
#    'daughter': True,
#    'great': True,
#    'howev': True,
#    'issu': True,
#    'learn': True,
#    'live': True,
#    'phone': True,
#    'small': True},
#   'positive'),
#  ({'came': True,
#    'describ': True,
#    'exact': True,
#    'happi': True,
#    'iphon': True,
#    'purchas': True},
#   'positive'),
#  ({'deliveri': True, 'great': True, 'price': True, 'speed': True}, 'positive'),
#  ({'amaz': True, 'deal': True, 'great': True, 'work': True}, 'positive'),
#  ({'great': True, 'work': True}, 'positive'),
#  ({'good': True}, 'positive'),
#  ({'good': True, 'work': True}, 'positive'),
#  ({'happi': True, 'one': True}, 'positive'),
#  ({'crush': True}, 'positive'),
#  ({'alway': True,
#    'arriv': True,
#    'brand': True,
#    'could': True,
#    'date': True,
#    'got': True,
#    'happier': True,
#    'lie': True,
#    'new': True,
#    'phone': True,
#    'plus': True,
#    'post': True,
#    'well': True},
#   'positive'),
#  ({'describ': True,
#    'everyth': True,
#    'far': True,
#    'fast': True,
#    'fine': True,
#    'good': True,
#    'month': True,
#    'phone': True,
#    'price': True,
#    'right': True,
#    'ship': True,
#    'super': True,
#    'work': True},
#   'positive'),
#  ({'amaz': True}, 'positive'),
#  ({'2': True,
#    '6': True,
#    'brand': True,
#    'day': True,
#    'got': True,
#    'great': True,
#    'high': True,
#    'iphon': True,
#    'like': True,
#    'look': True,
#    'lost': True,
#    'mine': True,
#    'new': True,
#    'price': True,
#    'recommend': True,
#    'refurbish': True,
#    'seller': True,
#    'work': True},
#   'positive'),
#  ({'awesom': True, 'complaint': True, 'phone': True}, 'positive'),
#  ({'best': True, 'ever': True, 'phone': True}, 'positive'),
#  ({'happi': True, 'phone': True}, 'positive'),
#  ({'4s': True,
#    'bit': True,
#    'button': True,
#    'chang': True,
#    'click': True,
#    'cuz': True,
#    'definit': True,
#    'differ': True,
#    'edg': True,
#    'fast': True,
#    'fingerprint': True,
#    'help': True,
#    'home': True,
#    'less': True,
#    'lighter': True,
#    'like': True,
#    'longer': True,
#    'louder': True,
#    'major': True,
#    'much': True,
#    'previous': True,
#    'reach': True,
#    'reachabl': True,
#    'round': True,
#    'screen': True,
#    'see': True,
#    'sensor': True,
#    'side': True,
#    'skinnier': True,
#    'sleep': True,
#    'slight': True,
#    'sound': True,
#    'still': True,
#    'sweet': True,
#    'thing': True,
#    'though': True,
#    'upgrad': True,
#    'vibrat': True,
#    'wider': True,
#    'wish': True,
#    'word': True,
#    'worth': True,
#    'zoom': True},
#   'positive'),
#  ({'came': True,
#    'clean': True,
#    'day': True,
#    'earlier': True,
#    'great': True,
#    'iphon': True,
#    'work': True},
#   'positive'),
#  ({'great': True}, 'positive'),
#  ({}, 'positive'),
#  ({'16gb': True,
#    'box': True,
#    'brand': True,
#    'charger': True,
#    'clear': True,
#    'code': True,
#    'compat': True,
#    'cord': True,
#    'could': True,
#    'enter': True,
#    'etc': True,
#    'factori': True,
#    'grey': True,
#    'gsm': True,
#    'headphon': True,
#    'high': True,
#    'imei': True,
#    'iphon': True,
#    'know': True,
#    'mobil': True,
#    'network': True,
#    'new': True,
#    'nick': True,
#    'order': True,
#    'phone': True,
#    'pleas': True,
#    'plug': True,
#    'pristin': True,
#    'receiv': True,
#    'recommend': True,
#    'satisfi': True,
#    'scratch': True,
#    'screen': True,
#    'seal': True,
#    'serial': True,
#    'space': True,
#    'told': True,
#    'usb': True,
#    'verizon': True,
#    'websit': True,
#    'work': True,
#    'would': True},
#   'positive'),
#  ({'describ': True,
#    'network': True,
#    'perfect': True,
#    'tracfon': True,
#    'verizon': True,
#    'work': True},
#   'positive'),
#  ({'perfect': True, 'yes': True}, 'positive'),
#  ({'analyz': True,
#    'around': True,
#    'bit': True,
#    'complaint': True,
#    'condit': True,
#    'edg': True,
#    'ever': True,
#    'faster': True,
#    'great': True,
#    'love': True,
#    'minor': True,
#    'order': True,
#    'phone': True,
#    'realli': True,
#    'scratch': True,
#    'see': True,
#    'ship': True,
#    'sinc': True,
#    'time': True,
#    'wish': True,
#    'work': True,
#    'would': True},
#   'positive'),
#  ({'batteri': True,
#    'beauti': True,
#    'came': True,
#    'complaint': True,
#    'got': True,
#    'life': True,
#    'like': True,
#    'look': True,
#    'low': True,
#    'month': True,
#    'new': True,
#    'otherwis': True,
#    'phone': True,
#    'quick': True,
#    'sinc': True,
#    'three': True,
#    'wonder': True},
#   'positive'),
#  ({'6': True,
#    'bought': True,
#    'compani': True,
#    'complex': True,
#    'day': True,
#    'deliv': True,
#    'five': True,
#    'friend': True,
#    'iphon': True,
#    'issu': True,
#    'less': True,
#    'love': True,
#    'melodi': True,
#    'niec': True,
#    'overal': True,
#    'phone': True,
#    'receiv': True,
#    'recommend': True,
#    'satisfi': True,
#    'sinc': True,
#    'would': True},
#   'positive'),
#  ({'4': True,
#    'ago': True,
#    'arriv': True,
#    'bad': True,
#    'could': True,
#    'day': True,
#    'decid': True,
#    'descript': True,
#    'experi': True,
#    'far': True,
#    'first': True,
#    'forward': True,
#    'glad': True,
#    'go': True,
#    'good': True,
#    'great': True,
#    'happier': True,
#    'hope': True,
#    'huge': True,
#    'iphone5': True,
#    'iphone7': True,
#    'know': True,
#    'let': True,
#    'listen': True,
#    'littl': True,
#    'love': True,
#    'made': True,
#    'make': True,
#    'market': True,
#    'negat': True,
#    'new': True,
#    'nice': True,
#    'own': True,
#    'past': True,
#    'phone': True,
#    'prici': True,
#    'promis': True,
#    'purchas': True,
#    'quick': True,
#    'read': True,
#    'realli': True,
#    'refurbish': True,
#    'review': True,
#    'said': True,
#    'scratch': True,
#    'seller': True,
#    'skeptic': True,
#    'smart': True,
#    'spot': True,
#    'time': True,
#    'truli': True,
#    'upgrad': True,
#    'use': True,
#    'worth': True,
#    'year': True},
#   'positive'),
#  ({'appl': True,
#    'best': True,
#    'buy': True,
#    'condit': True,
#    'cord': True,
#    'everyth': True,
#    'get': True,
#    'got': True,
#    'know': True,
#    'never': True,
#    'onlin': True,
#    'organ': True,
#    'packag': True,
#    'perfect': True,
#    'phone': True,
#    'pleas': True,
#    'pleasant': True,
#    'recommend': True,
#    'review': True,
#    'skeptic': True,
#    'surpris': True,
#    'well': True,
#    'worth': True},
#   'positive'),
#  ({'easi': True,
#    'exact': True,
#    'got': True,
#    'great': True,
#    'high': True,
#    'order': True,
#    'process': True,
#    'product': True,
#    'quick': True,
#    'recommend': True,
#    'super': True,
#    'whole': True},
#   'positive'),
#  ({'arriv': True,
#    'condit': True,
#    'correct': True,
#    'like': True,
#    'mobilei': True,
#    'model': True,
#    'new': True,
#    'perfect': True,
#    'phone': True,
#    'verizon': True,
#    'work': True},
#   'positive'),
#  ({'best': True,
#    'brand': True,
#    'ive': True,
#    'look': True,
#    'new': True,
#    'phone': True,
#    'reciev': True,
#    'scratch': True},
#   'positive'),
#  ({'awesom': True}, 'positive'),
#  ({'adequ': True,
#    'basic': True,
#    'microphon': True,
#    'otherwis': True,
#    'siri': True,
#    'talk': True,
#    'text': True,
#    'voic': True,
#    'work': True},
#   'positive'),
#  ({'condit': True,
#    'good': True,
#    'physic': True,
#    'pretti': True,
#    'well': True,
#    'work': True},
#   'positive'),
#  ({'perfect': True, 'work': True}, 'positive'),
#  ({'happi': True}, 'positive'),
#  ({'great': True}, 'positive'),
#  ({'bought': True,
#    'brand': True,
#    'condit': True,
#    'function': True,
#    'great': True,
#    'like': True,
#    'new': True,
#    'well': True},
#   'positive'),
#  ({'deal': True, 'good': True, 'great': True, 'product': True}, 'positive'),
#  ({'anoth': True,
#    'came': True,
#    'charg': True,
#    'day': True,
#    'descript': True,
#    'earlier': True,
#    'eta': True,
#    'everyth': True,
#    'glitch': True,
#    'plus': True,
#    'right': True,
#    'spot': True,
#    'zero': True},
#   'positive'),
#  ({'anoth': True,
#    'get': True,
#    'help': True,
#    'new': True,
#    'one': True,
#    'phone': True,
#    'want': True},
#   'positive'),
#  ({'far': True,
#    'fast': True,
#    'great': True,
#    'issu': True,
#    'item': True,
#    'order': True,
#    'quick': True,
#    'ship': True,
#    'work': True},
#   'positive'),
#  ({'gift': True, 'phone': True, 'pleas': True, 'purchas': True, 'wife': True},
#   'positive'),
#  ({'carrier': True,
#    'great': True,
#    'love': True,
#    'tracfon': True,
#    'work': True},
#   'positive'),
#  ({'amazon': True,
#    'best': True,
#    'know': True,
#    'long': True,
#    'phone': True,
#    'pick': True,
#    'seller': True,
#    'thank': True,
#    'time': True,
#    'veer': True},
#   'positive'),
#  ({'good': True, 'grandson': True, 'product': True, 'proud': True},
#   'positive'),
#  ({'6': True,
#    'abl': True,
#    'account': True,
#    'activ': True,
#    'ad': True,
#    'also': True,
#    'came': True,
#    'card': True,
#    'come': True,
#    'daughter': True,
#    'get': True,
#    'got': True,
#    'hoop': True,
#    'iphon': True,
#    'jump': True,
#    'like': True,
#    'list': True,
#    'littl': True,
#    'love': True,
#    'mislead': True,
#    'network': True,
#    'phone': True,
#    'product': True,
#    'realli': True,
#    'said': True,
#    'say': True,
#    'sim': True,
#    'sinc': True,
#    'store': True,
#    'though': True,
#    'took': True,
#    'verizon': True,
#    'wireless': True,
#    'work': True,
#    'would': True},
#   'positive'),
#  ({'best': True, 'ever': True, 'iphon': True}, 'positive'),
#  ({'came': True, 'perfect': True, 'phone': True, 'time': True}, 'positive'),
#  ({'advertis': True,
#    'arriv': True,
#    'exact': True,
#    'expect': True,
#    'fine': True,
#    'item': True,
#    'pleas': True,
#    'purchas': True,
#    'time': True,
#    'work': True},
#   'positive'),
#  ({'buy': True,
#    'came': True,
#    'earli': True,
#    'everyth': True,
#    'new': True,
#    'page': True,
#    'phone': True,
#    'pleas': True,
#    'recommend': True,
#    'said': True,
#    'thank': True},
#   'positive'),
#  ({'condit': True,
#    'excel': True,
#    'fianc': True,
#    'love': True,
#    'new': True,
#    'perfect': True,
#    'phone': True,
#    'price': True},
#   'positive'),
#  ({'came': True, 'describ': True, 'impress': True, 'phone': True}, 'positive'),
#  ({'best': True, 'ever': True, 'iphon': True}, 'positive'),
#  ({'excel': True}, 'positive'),
#  ({'condit': True, 'got': True, 'great': True, 'realli': True}, 'positive'),
#  ({'coolest': True, 'ever': True, 'phone': True}, 'positive'),
#  ({'thank': True}, 'positive'),
#  ({'boost': True,
#    'easi': True,
#    'fine': True,
#    'mobil': True,
#    'phone': True,
#    'transit': True,
#    'well': True,
#    'work': True},
#   'positive'),
#  ({}, 'positive'),
#  ({'6': True,
#    'appl': True,
#    'button': True,
#    'design': True,
#    'good': True,
#    'iphon': True,
#    'like': True,
#    'oper': True,
#    'phone': True,
#    'power': True,
#    'product': True,
#    'side': True,
#    'simplist': True,
#    'solid': True,
#    'system': True,
#    'thinner': True},
#   'positive'),
#  ({'anyth': True,
#    'awesom': True,
#    'card': True,
#    'contact': True,
#    'courtesi': True,
#    'describ': True,
#    'feel': True,
#    'found': True,
#    'free': True,
#    'great': True,
#    'insid': True,
#    'love': True,
#    'phone': True,
#    'pretti': True,
#    'say': True,
#    'wrong': True},
#   'positive'),
#  ({'awesom': True}, 'positive'),
#  ({'6': True,
#    'ago': True,
#    'also': True,
#    'bought': True,
#    'care': True,
#    'go': True,
#    'good': True,
#    'great': True,
#    'iphon': True,
#    'machin': True,
#    'purchas': True,
#    'still': True,
#    'strong': True,
#    'use': True,
#    'year': True},
#   'positive'),
#  ({'best': True, 'ever': True, 'iphon': True, 'pleas': True, 'purchas': True},
#   'positive'),
#  ({'5': True,
#    'activ': True,
#    'advertis': True,
#    'beauti': True,
#    'color': True,
#    'custom': True,
#    'day': True,
#    'excel': True,
#    'got': True,
#    'gray': True,
#    'happi': True,
#    'immedi': True,
#    'packag': True,
#    'perfect': True,
#    'phone': True,
#    'pictur': True,
#    'purchas': True,
#    'rate': True,
#    'servic': True,
#    'ship': True,
#    'space': True,
#    'three': True,
#    'work': True},
#   'positive'),
#  ({'love': True, 'phone': True}, 'positive'),
#  ({'came': True, 'earlier': True, 'expect': True, 'satisfi': True},
#   'positive'),
#  ({'excel': True}, 'positive'),
#  ({'great': True, 'overal': True}, 'positive'),
#  ({'abl': True,
#    'ahead': True,
#    'cabl': True,
#    'charg': True,
#    'condit': True,
#    'correct': True,
#    'deliv': True,
#    'great': True,
#    'intermitt': True,
#    'issu': True,
#    'mint': True,
#    'proper': True,
#    'schedul': True,
#    'seat': True,
#    'work': True},
#   'positive'),
#  ({'buy': True,
#    'condit': True,
#    'fan': True,
#    'flawless': True,
#    'great': True,
#    'refurbish': True,
#    'stuff': True,
#    'work': True},
#   'positive'),
#  ({'deliveri': True,
#    'flawless': True,
#    'perfect': True,
#    'pleas': True,
#    'quick': True,
#    'readi': True,
#    'use': True},
#   'positive'),
#  ({'explan': True, 'good': True, 'need': True, 'simpli': True}, 'positive'),
#  ({'buy': True,
#    'cell': True,
#    'exel': True,
#    'great': True,
#    'happi': True,
#    'iphon': True,
#    'l': True,
#    'like': True,
#    'perfect': True,
#    'work': True},
#   'positive'),
#  ({'everyth': True,
#    'go': True,
#    'love': True,
#    'neeeeedddd': True,
#    'onnnnn': True,
#    'talk': True,
#    'want': True},
#   'positive'),
#  ({'allow': True,
#    'appl': True,
#    'custom': True,
#    'fact': True,
#    'freedom': True,
#    'great': True,
#    'like': True,
#    'littl': True,
#    'phone': True},
#   'positive'),
#  ({'god': True}, 'positive'),
#  ({'broken': True,
#    'charger': True,
#    'got': True,
#    'great': True,
#    'perfect': True,
#    'phone': True},
#   'positive'),
#  ({'6': True,
#    'appl': True,
#    'arriv': True,
#    'devic': True,
#    'expect': True,
#    'far': True,
#    'great': True,
#    'iphon': True,
#    'love': True,
#    'phone': True,
#    'problem': True,
#    'product': True,
#    'sooner': True,
#    'stand': True,
#    'zero': True},
#   'positive'),
#  ({'6': True, 'iphon': True, 'love': True}, 'positive'),
#  ({'advertis': True, 'thank': True}, 'positive'),
#  ({'describ': True,
#    'exact': True,
#    'quick': True,
#    'start': True,
#    'surpris': True,
#    'unlock': True,
#    'work': True},
#   'positive'),
#  ({'came': True,
#    'card': True,
#    'charger': True,
#    'headphon': True,
#    'lock': True,
#    'love': True,
#    'minor': True,
#    'need': True,
#    'phone': True,
#    'problem': True,
#    'satisfi': True,
#    'sim': True},
#   'positive'),
#  ({'10': True,
#    'activ': True,
#    'custom': True,
#    'eas': True,
#    'great': True,
#    'impress': True,
#    'look': True,
#    'minut': True,
#    'new': True,
#    'overal': True,
#    'phone': True,
#    'purchas': True,
#    'servic': True,
#    'support': True,
#    'took': True,
#    'work': True},
#   'positive'),
#  ({'describ': True,
#    'favorit': True,
#    'got': True,
#    'great': True,
#    'sender': True,
#    'usp': True,
#    'work': True},
#   'positive'),
#  ({'great': True, 'like': True, 'new': True, 'work': True}, 'positive'),
#  ({'batteri': True,
#    'charg': True,
#    'condit': True,
#    'good': True,
#    'lost': True,
#    'phone': True,
#    'quick': True},
#   'positive'),
#  ({'busi': True,
#    'compani': True,
#    'good': True,
#    'phone': True,
#    'pleasur': True},
#   'positive'),
#  ({'gucci': True}, 'positive'),
#  ({'buy': True, 'buyer': True, 'great': True, 'work': True, 'would': True},
#   'positive'),
#  ({'activ': True,
#    'aluminum': True,
#    'back': True,
#    'bare': True,
#    'came': True,
#    'charg': True,
#    'first': True,
#    'free': True,
#    'great': True,
#    'notic': True,
#    'scratch': True,
#    'small': True,
#    'sprint': True,
#    'take': True,
#    'understand': True,
#    'use': True,
#    'well': True,
#    'work': True},
#   'positive'),
#  ({'came': True,
#    'cheaper': True,
#    'earli': True,
#    'great': True,
#    'store': True,
#    'suppos': True,
#    'work': True},
#   'positive'),
#  ({'anoth': True, 'good': True, 'know': True, 'person': True, 'us': True},
#   'positive'),
#  ({'best': True}, 'positive'),
#  ({'arriv': True,
#    'daughter': True,
#    'good': True,
#    'manner': True,
#    'pleas': True,
#    'price': True,
#    'purchas': True,
#    'time': True},
#   'positive'),
#  ({'beauti': True, 'effici': True, 'phone': True, 'work': True}, 'positive'),
#  ({'cheap': True, 'phone': True, 'prive': True, 'quaili': True}, 'positive'),
#  ({'arriv': True,
#    'great': True,
#    'like': True,
#    'new': True,
#    'phone': True,
#    'problem': True,
#    'qualiti': True},
#   'positive'),
#  ({'appreci': True,
#    'card': True,
#    'charger': True,
#    'fast': True,
#    'gift': True,
#    'great': True,
#    'new': True,
#    'one': True,
#    'plus': True,
#    'sent': True,
#    'ship': True,
#    'wonder': True,
#    'work': True},
#   'positive'),
#  ({'great': True, 'phone': True}, 'positive'),
#  ({'6': True,
#    'android': True,
#    'chang': True,
#    'got': True,
#    'great': True,
#    'iphon': True,
#    'love': True,
#    'new': True,
#    'phone': True,
#    'practic': True,
#    'thank': True,
#    'today': True,
#    'user': True},
#   'positive'),
#  ({'grandbabi': True, 'love': True, 'phone': True, 'purchas': True},
#   'positive'),
#  ({'50': True,
#    '6': True,
#    'amazon': True,
#    'better': True,
#    'contract': True,
#    'deal': True,
#    'get': True,
#    'great': True,
#    'iphon': True,
#    'plan': True,
#    'servic': True,
#    'sprint': True,
#    'trap': True,
#    'vs': True},
#   'positive'),
# ...
#  ({'carrier': True,
#    'differ': True,
#    'great': True,
#    'love': True,
#    'tracfon': True,
#    'work': True},
#   'positive'),
#  ({'love': True, 'perfect': True, 'wife': True}, 'positive'),
#  ({'brand': True,
#    'complain': True,
#    'new': True,
#    'open': True,
#    'pretti': True,
#    'purchas': True,
#    'stratifi': True,
#    'wit': True},
#   'positive'),
#  ({'6': True,
#    '6plus': True,
#    '6s': True,
#    'better': True,
#    'big': True,
#    'care': True,
#    'differ': True,
#    'dont': True,
#    'far': True,
#    'got': True,
#    'great': True,
#    'iphon': True,
#    'like': True,
#    'one': True,
#    'phone': True,
#    'purchas': True,
#    'realli': True,
#    'size': True,
#    'sure': True,
#    'vender': True,
#    'would': True},
#   'positive'),
#  ({'came': True,
#    'expect': True,
#    'far': True,
#    'great': True,
#    'problem': True,
#    'work': True},
#   'positive'),
#  ({'love': True}, 'positive'),
#  ({'condit': True,
#    'fast': True,
#    'good': True,
#    'love': True,
#    'ship': True,
#    'work': True},
#   'positive'),
#  ({'adapt': True,
#    'also': True,
#    'appl': True,
#    'beyond': True,
#    'came': True,
#    'card': True,
#    'case': True,
#    'charger': True,
#    'crack': True,
#    'custom': True,
#    'ear': True,
#    'everyth': True,
#    'explain': True,
#    'got': True,
#    'great': True,
#    'happi': True,
#    'like': True,
#    'look': True,
#    'mine': True,
#    'new': True,
#    'one': True,
#    'packag': True,
#    'phone': True,
#    'pleas': True,
#    'purchas': True,
#    'put': True,
#    'scratch': True,
#    'sim': True,
#    'straight': True,
#    'talk': True,
#    'that': True,
#    'unlock': True,
#    'wall': True,
#    'well': True,
#    'wonder': True,
#    'work': True},
#   'positive'),
#  ({'could': True, 'fail': True, 'imei': True, 'payment': True, 'unlock': True},
#   'positive'),
#  ({'brand': True,
#    'came': True,
#    'clean': True,
#    'crack': True,
#    'deal': True,
#    'dent': True,
#    'howev': True,
#    'imei': True,
#    'know': True,
#    'love': True,
#    'name': True,
#    'new': True,
#    'order': True,
#    'panda': True,
#    'panga': True,
#    'phone': True,
#    'problem': True,
#    'recommend': True,
#    'refurbish': True,
#    'say': True,
#    'see': True},
#   'positive'),
#  ({'amaz': True,
#    'better': True,
#    'come': True,
#    'condit': True,
#    'expect': True,
#    'good': True,
#    'got': True,
#    'iphon': True,
#    'littl': True,
#    'money': True,
#    'phone': True,
#    'product': True,
#    'qualiti': True,
#    'rate': True,
#    'speak': True,
#    'want': True,
#    'well': True,
#    'worth': True},
#   'positive'),
#  ({'love': True}, 'positive'),
#  ({'condit': True,
#    'cosmet': True,
#    'far': True,
#    'good': True,
#    'perfect': True,
#    'problem': True,
#    'purchas': True},
#   'positive'),
#  ({'nice': True}, 'positive'),
#  ({'arriv': True,
#    'att': True,
#    'card': True,
#    'great': True,
#    'order': True,
#    'phone': True,
#    'sim': True,
#    'verizon': True},
#   'positive'),
#  ({'good': True}, 'positive'),
#  ({'describ': True, 'product': True, 'satisfi': True}, 'positive'),
#  ({'awsom': True, 'perfect': True}, 'positive'),
#  ({'great': True, 'phone': True}, 'positive'),
#  ({'charger': True, 'excel': True, 'phone': True, 'work': True}, 'positive'),
#  ({'iphon': True, 'problem': True, 'time': True}, 'positive'),
#  ({'anyth': True,
#    'box': True,
#    'flaw': True,
#    'great': True,
#    'phone': True,
#    'right': True,
#    'work': True},
#   'positive'),
#  ({'almost': True,
#    'bodi': True,
#    'brand': True,
#    'damag': True,
#    'exceed': True,
#    'expect': True,
#    'great': True,
#    'look': True,
#    'new': True,
#    'order': True,
#    'phone': True,
#    'refurbish': True,
#    'respons': True,
#    'screen': True,
#    'touch': True,
#    'visibl': True,
#    'work': True},
#   'positive'),
#  ({'absolut': True,
#    'book': True,
#    'crazi': True,
#    'funni': True,
#    'glu': True,
#    'hand': True,
#    'masterpiec': True,
#    'mean': True,
#    'mother': True,
#    'pant': True,
#    'pee': True,
#    'put': True,
#    'stand': True},
#   'positive'),
#  ({'awesom': True,
#    'came': True,
#    'earli': True,
#    'easi': True,
#    'far': True,
#    'phone': True,
#    'scrape': True,
#    'scratch': True,
#    'set': True,
#    'wonder': True},
#   'positive'),
#  ({'also': True,
#    'condit': True,
#    'fast': True,
#    'good': True,
#    'great': True,
#    'love': True,
#    'ship': True,
#    'work': True},
#   'positive'),
#  ({'exact': True, 'expect': True}, 'positive'),
#  ({'good': True, 'phone': True, 'thank': True}, 'positive'),
#  ({'far': True,
#    'good': True,
#    'great': True,
#    'phone': True,
#    'realli': True,
#    'work': True},
#   'positive'),
#  ({'ok': True}, 'positive'),
#  ({'4': True,
#    '5': True,
#    'give': True,
#    'great': True,
#    'iphon': True,
#    'overal': True,
#    'solid': True},
#   'positive'),
#  ({'describ': True, 'like': True, 'perfect': True, 'tks': True}, 'positive'),
#  ({'great': True, 'phone': True, 'price': True}, 'positive'),
#  ({'big': True,
#    'chanc': True,
#    'gambl': True,
#    'new': True,
#    'paid': True,
#    'purchas': True,
#    'seller': True,
#    'took': True,
#    '¾': True,
#    'ðÿ': True,
#    'œðÿ': True},
#   'positive'),
#  ({'date': True,
#    'deliveri': True,
#    'descript': True,
#    'expect': True,
#    'got': True,
#    'met': True},
#   'positive'),
#  ({'amaz': True, 'cam': True, 'earli': True, 'product': True}, 'positive'),
#  ({'came': True,
#    'issu': True,
#    'maintain': True,
#    'month': True,
#    'one': True,
#    'order': True,
#    'perfect': True,
#    'phone': True,
#    'whatsoev': True,
#    'work': True},
#   'positive'),
#  ({'deliv': True,
#    'excel': True,
#    'matter': True,
#    'product': True,
#    'satisfi': True,
#    'seller': True,
#    'thank': True,
#    'time': True},
#   'positive'),
#  ({'condit': True, 'excel': True, 'phone': True, 'physic': True}, 'positive'),
#  ({'ago': True,
#    'good': True,
#    'got': True,
#    'money': True,
#    'month': True,
#    'order': True,
#    'phone': True,
#    'save': True,
#    'sever': True},
#   'positive'),
#  ({'amaz': True,
#    'excel': True,
#    'phone': True,
#    'provid': True,
#    'seller': True,
#    'servic': True},
#   'positive'),
#  ({'appl': True,
#    'arriv': True,
#    'describ': True,
#    'great': True,
#    'item': True,
#    'nice': True,
#    'order': True,
#    'packag': True,
#    'phone': True,
#    'quick': True,
#    'work': True},
#   'positive'),
#  ({'arriv': True,
#    'auction': True,
#    'better': True,
#    'day': True,
#    'describ': True,
#    'earlier': True,
#    'expect': True,
#    'extrem': True,
#    'item': True,
#    'jd': True,
#    'mine': True,
#    'model': True,
#    'perfect': True,
#    'pleas': True,
#    'purchas': True,
#    'seller': True,
#    'ship': True,
#    'unlock': True,
#    'warehous': True,
#    'work': True},
#   'positive'),
#  ({'condit': True, 'good': True, 'great': True, 'work': True}, 'positive'),
#  ({'absolut': True,
#    'great': True,
#    'happi': True,
#    'phone': True,
#    'purchas': True},
#   'positive'),
#  ({'exact': True, 'need': True, 'phone': True}, 'positive'),
#  ({'great': True}, 'positive'),
#  ({'6': True,
#    'appl': True,
#    'best': True,
#    'call': True,
#    'care': True,
#    'coast': True,
#    'coastal': True,
#    'communic': True,
#    'compani': True,
#    'ecuador': True,
#    'ecuadorian': True,
#    'estat': True,
#    'face': True,
#    'free': True,
#    'iphon': True,
#    'largest': True,
#    'live': True,
#    'part': True,
#    'phone': True,
#    'problem': True,
#    'properti': True,
#    'real': True,
#    'reward': True,
#    'run': True,
#    'taken': True,
#    'thru': True,
#    'time': True},
#   'positive'),
#  ({'perfect': True}, 'positive'),
#  ({'excel': True, 'expect': True}, 'positive'),
#  ({'excel': True}, 'positive'),
#  ({'arriv': True, 'excel': True, 'phone': True, 'promis': True}, 'positive'),
#  ({'buy': True,
#    'easi': True,
#    'expect': True,
#    'great': True,
#    'item': True,
#    'luv': True,
#    'phone': True,
#    'seller': True,
#    'set': True,
#    'unopen': True,
#    'would': True},
#   'positive'),
#  ({'excel': True, 'happi': True}, 'positive'),
#  ({'excelent': True}, 'positive'),
#  ({'best': True, 'iphon': True, 'market': True, 'right': True}, 'positive'),
#  ({'brand': True,
#    'fine': True,
#    'like': True,
#    'new': True,
#    'phone': True,
#    'work': True},
#   'positive'),
#  ({'day': True,
#    'deliveri': True,
#    'everyth': True,
#    'iphon': True,
#    'last': True,
#    'perfect': True,
#    'product': True,
#    'realli': True,
#    'reciev': True,
#    'well': True,
#    'work': True},
#   'positive'),
#  ({'brand': True,
#    'describ': True,
#    'devic': True,
#    'excel': True,
#    'help': True,
#    'lot': True,
#    'new': True,
#    'seller': True},
#   'positive'),
#  ({'great': True, 'size': True}, 'positive'),
#  ({'daughter': True,
#    'good': True,
#    'got': True,
#    'much': True,
#    'price': True,
#    'thank': True},
#   'positive'),
#  ({'3': True,
#    '6s': True,
#    'complet': True,
#    'everyon': True,
#    'grandchildren': True,
#    'iphon': True,
#    'purchas': True,
#    'satisfi': True},
#   'positive'),
#  ({'longer': True, 'need': True, 'return': True, 'unopen': True}, 'positive'),
#  ({'assembl': True, 'easi': True, 'product': True, 'solid': True}, 'positive'),
#  ({'came': True,
#    'perfect': True,
#    'phone': True,
#    'quick': True,
#    'work': True,
#    'ðÿ': True},
#   'positive'),
#  ({'nice': True}, 'positive'),
#  ({'everi': True, 'great': True, 'penni': True, 'worth': True}, 'positive'),
#  ({'els': True,
#    'everyth': True,
#    'great': True,
#    'iphon': True,
#    'much': True,
#    'otherwis': True,
#    'phone': True,
#    'previous': True,
#    'sound': True,
#    'tinni': True},
#   'positive'),
#  ({'deal': True, 'excel': True}, 'positive'),
#  ({'absolut': True,
#    'great': True,
#    'lg': True,
#    'perfect': True,
#    'phone': True,
#    'seller': True,
#    'switch': True,
#    'wow': True},
#   'positive'),
#  ({'good': True, 'like': True, 'phone': True, 'ï': True}, 'positive'),
#  ({'good': True, 'phone': True}, 'positive'),
#  ({'exel': True, 'ok': True}, 'positive'),
#  ({'problem': True, 'singl': True}, 'positive'),
#  ({'describ': True}, 'positive'),
#  ({'excel': True, 'phone': True}, 'positive'),
#  ({'curv': True,
#    'ipod': True,
#    'learn': True,
#    'less': True,
#    'other': True,
#    'recommend': True,
#    'sever': True,
#    'touch': True,
#    'use': True,
#    'year': True},
#   'positive'),
#  ({'bug': True,
#    'buy': True,
#    'definit': True,
#    'excel': True,
#    'futur': True,
#    'issu': True,
#    'like': True,
#    'new': True,
#    'refurb': True,
#    'valu': True,
#    'would': True},
#   'positive'),
#  ({'advertis': True, 'perfect': True, 'work': True}, 'positive'),
#  ({'condit': True, 'everyth': True, 'great': True, 'love': True}, 'positive'),
#  ({'great': True, 'well': True, 'work': True}, 'positive'),
#  ({'5': True, 'bigger': True, 'iphon': True, 'love': True}, 'positive'),
#  ({'bc': True,
#    'could': True,
#    'decis': True,
#    'far': True,
#    'glad': True,
#    'got': True,
#    'great': True,
#    'happier': True,
#    'like': True,
#    'look': True,
#    'make': True,
#    'may': True,
#    'perfect': True,
#    'phone': True,
#    'price': True,
#    'refurbish': True,
#    'seem': True,
#    'spend': True,
#    'sure': True,
#    'thank': True,
#    'time': True,
#    'work': True},
#   'positive'),
#  ({'ok': True}, 'positive'),
#  ({'advertis': True,
#    'deliveri': True,
#    'good': True,
#    'new': True,
#    'particular': True,
#    'price': True,
#    'product': True,
#    'see': True,
#    'slower': True},
#   'positive'),
#  ({'discount': True, 'great': True, 'phone': True, 'tremend': True},
#   'positive'),
#  ({'00': True,
#    '370': True,
#    'bought': True,
#    'condit': True,
#    'describ': True,
#    'great': True,
#    'look': True,
#    'model': True,
#    'new': True,
#    'receiv': True,
#    'refurbish': True,
#    'work': True},
#   'positive'),
#  ({'6': True,
#    'almost': True,
#    'app': True,
#    'appl': True,
#    'blemish': True,
#    'came': True,
#    'condit': True,
#    'easi': True,
#    'easier': True,
#    'exceed': True,
#    'expect': True,
#    'fact': True,
#    'iphon': True,
#    'life': True,
#    'like': True,
#    'make': True,
#    'met': True,
#    'much': True,
#    'perfect': True,
#    'phone': True,
#    'side': True,
#    'small': True,
#    'updat': True,
#    'us': True,
#    'use': True},
#   'positive'),
#  ({'condit': True, 'describ': True, 'excel': True, 'receiv': True},
#   'positive'),
#  ({'daughter': True, 'exact': True, 'expect': True, 'love': True}, 'positive'),
#  ({'adapt': True,
#    'also': True,
#    'appl': True,
#    'beyond': True,
#    'came': True,
#    'card': True,
#    'case': True,
#    'charger': True,
#    'crack': True,
#    'custom': True,
#    'ear': True,
#    'everyth': True,
#    'explain': True,
#    'got': True,
#    'great': True,
#    'happi': True,
#    'like': True,
#    'look': True,
#    'mine': True,
#    'new': True,
#    'one': True,
#    'packag': True,
#    'phone': True,
#    'pleas': True,
#    'purchas': True,
#    'put': True,
#    'scratch': True,
#    'sim': True,
#    'straight': True,
#    'talk': True,
#    'that': True,
#    'unlock': True,
#    'wall': True,
#    'well': True,
#    'wonder': True,
#    'work': True},
#   'positive'),
#  ({'iphon': True, 'love': True}, 'positive'),
#  ({'5': True,
#    'came': True,
#    'describ': True,
#    'exact': True,
#    'rate': True,
#    'star': True},
#   'positive'),
#  ({'4': True,
#    'brought': True,
#    'came': True,
#    'color': True,
#    'complet': True,
#    'comput': True,
#    'condit': True,
#    'fast': True,
#    'gave': True,
#    'good': True,
#    'grey': True,
#    'look': True,
#    'new': True,
#    'password': True,
#    'perfect': True,
#    'phone': True,
#    'product': True,
#    'reset': True,
#    'ship': True,
#    'silver': True,
#    'sister': True,
#    'star': True,
#    'thank': True},
#   'positive'),
#  ({'bought': True, 'christma': True, 'husband': True, 'perfect': True},
#   'positive'),
#  ({'400': True,
#    'background': True,
#    'besid': True,
#    'best': True,
#    'buy': True,
#    'cabl': True,
#    'charger': True,
#    'condit': True,
#    'cosmet': True,
#    'great': True,
#    'hard': True,
#    'headphon': True,
#    'less': True,
#    'minim': True,
#    'notic': True,
#    'receiv': True,
#    'regard': True,
#    'scratch': True,
#    'small': True,
#    'thank': True,
#    'unless': True,
#    'usb': True,
#    'view': True,
#    'white': True,
#    'ðÿ': True,
#    'ƒ': True},
#   'positive'),
#  ({'back': True,
#    'brand': True,
#    'corner': True,
#    'even': True,
#    'front': True,
#    'gap': True,
#    'get': True,
#    'guy': True,
#    'hand': True,
#    'high': True,
#    'money': True,
#    'much': True,
#    'new': True,
#    'notic': True,
#    'phone': True,
#    'point': True,
#    'recommend': True,
#    'save': True,
#    'scratch': True,
#    'second': True,
#    'small': True,
#    'worth': True},
#   'positive'),
#  ({'absolut': True,
#    'best': True,
#    'ever': True,
#    'flawless': True,
#    'invest': True,
#    'phone': True,
#    'pleas': True,
#    'purchas': True,
#    'quick': True,
#    'ship': True},
#   'positive'),
#  ({'1': True,
#    '10': True,
#    '140': True,
#    '6': True,
#    '6s': True,
#    '70': True,
#    'appl': True,
#    'batteri': True,
#    'bodi': True,
#    'chang': True,
#    'charg': True,
#    'check': True,
#    'cycl': True,
#    'day': True,
#    'describ': True,
#    'devic': True,
#    'everi': True,
#    'found': True,
#    'full': True,
#    'good': True,
#    'gsm': True,
#    'iphon': True,
#    'left': True,
#    'light': True,
#    'like': True,
#    'mobil': True,
#    'month': True,
#    'new': True,
#    'old': True,
#    'order': True,
#    'phone': True,
#    'pristin': True,
#    'ran': True,
#    'scratch': True,
#    'screen': True,
#    'still': True,
#    'stuff': True,
#    'tini': True,
#    'use': True,
#    'warrante': True,
#    'work': True},
#   'positive'),
#  ({'200': True,
#    '6': True,
#    'accessori': True,
#    'along': True,
#    'box': True,
#    'brainer': True,
#    'brand': True,
#    'came': True,
#    'cost': True,
#    'crazi': True,
#    'custom': True,
#    'display': True,
#    'either': True,
#    'essenti': True,
#    'except': True,
#    'ident': True,
#    'includ': True,
#    'iphon': True,
#    'kind': True,
#    'less': True,
#    'mark': True,
#    'new': True,
#    'obvious': True,
#    'origin': True,
#    'pay': True,
#    'peopl': True,
#    'phone': True,
#    'price': True,
#    'receiv': True,
#    'retail': True,
#    'return': True,
#    'scratch': True,
#    'somewher': True,
#    'store': True,
#    'use': True,
#    'would': True},
#   'positive'),
#  ({'happi': True, 'purchas': True}, 'positive'),
#  ({'great': True}, 'positive'),
#  ({'far': True, 'terrifi': True}, 'positive'),
#  ...]

# %%
neg_reviews = []

for i in data_neg['Reviews']:
    
    neg_reviews.append((create_word_features(i), "negative"))
    
print(len(neg_reviews))
# Out:
# 1028

# %%
i = random.sample(pos_reviews,  int(len(pos_reviews)*0.70))
j = random.sample(neg_reviews,  int(len(neg_reviews)*0.70))
train = i + j

# %%
print(len(train),  len(test))

# %%
test = [pos_reviews[k] for k in range(0,len(pos_reviews)) if k not in i] + [neg_reviews[k] for k in range(0,len(neg_reviews)) if k not in j]

# %% [markdown]
# Now, we train and test the model using the Naive Bayes Classifier.

# %%
#Model training
classifier = NaiveBayesClassifier.train(train)

# %%
#Model Validation
accuracy = nltk.classify.util.accuracy(classifier, train)
print(accuracy * 100)
print((1-accuracy) * 100)
# Out:
# 88.69172932330827
# 11.308270676691734

# %%
accuracy = nltk.classify.util.accuracy(classifier, test)
print(accuracy * 100)
print((1-accuracy) * 100)
# Out:
# 87.83670033670033
# 12.163299663299664

# %% [markdown]
# ### Method 2 : Naive Bayes Classifier

# %%
import pandas as pd
import nltk
import collections
import numpy as np

# %%
phone_data = pd.read_csv('Amazon_Unlocked_Mobile.csv', encoding='utf-8')

x = phone_data['Reviews']
y_num = phone_data['Rating']
y = np.where(y_num>3,'Positive','Negative')

# %%
size = int(len(y)*0.01)

x=x[:size]
y=y[:size]
y_num=y_num[:size]

x_words=collections.Counter(" ".join(str(i)for i in x).split()).most_common(2000)
x_word_features = list(a for (a,b) in x_words)

# %%
def review_features(review):
    review_words = set(review)
    features = {}
    for word in x_word_features:
        features['contains({})'.format(word)] = (word in review_words)
    return features
    
review=[(x[n],y_num[n]) for n in range(1,len(x))] 
    
review2=[(x.split(),y) for (x,y) in review]

featuresets = [(review_features(d), c) for (d,c) in review2]

featuresets
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
train_set2, test_set2 = featuresets[400:], featuresets[:400]

classifier = nltk.NaiveBayesClassifier.train(train_set2)
print(nltk.classify.accuracy(classifier, train_set2))
print(nltk.classify.accuracy(classifier, test_set2))

classifier.show_most_informative_features(30)
# Out:
# 0.689858175007
# 0.5175
# Most Informative Features
#          contains(waste) = True                1 : 5      =     50.6 : 1.0
#        contains(stopped) = True                2 : 5      =     44.4 : 1.0
#        contains(showing) = True                3 : 5      =     27.8 : 1.0
#           contains(face) = True                3 : 5      =     27.8 : 1.0
#   contains(unresponsive) = True                3 : 5      =     27.8 : 1.0
#         contains(failed) = True                3 : 5      =     27.8 : 1.0
#           contains(dead) = True                1 : 5      =     27.5 : 1.0
#          contains(stock) = True                4 : 1      =     24.7 : 1.0
#          contains(Tried) = True                1 : 5      =     23.7 : 1.0
#          contains(Large) = True                2 : 5      =     23.5 : 1.0
#         contains(repair) = True                2 : 5      =     23.5 : 1.0
#        contains(people.) = True                2 : 5      =     23.5 : 1.0
#        contains(message) = True                3 : 5      =     22.7 : 1.0
#      contains(settings,) = True                3 : 5      =     22.7 : 1.0
#       contains(glitches) = True                3 : 5      =     22.7 : 1.0
#           contains(onto) = True                3 : 5      =     22.7 : 1.0
#           contains(stay) = True                1 : 5      =     21.8 : 1.0
#         contains(messed) = True                1 : 5      =     21.8 : 1.0
#       contains(warranty) = True                3 : 5      =     20.6 : 1.0
#        contains(cracked) = True                3 : 5      =     20.6 : 1.0
#        contains(respond) = True                3 : 5      =     19.7 : 1.0
#            contains(So,) = True                3 : 5      =     19.7 : 1.0
#      contains(Excellent) = True                5 : 1      =     19.6 : 1.0
#       contains(features) = True                5 : 1      =     19.3 : 1.0
#           contains(menu) = True                4 : 5      =     19.2 : 1.0
#           contains(loud) = True                3 : 1      =     18.6 : 1.0
#           contains(Love) = True                5 : 1      =     18.6 : 1.0
#        contains(suppose) = True                2 : 5      =     18.3 : 1.0
#  contains(notifications) = True                2 : 5      =     18.3 : 1.0
#         contains(wasted) = True                1 : 5      =     18.0 : 1.0

# %% [markdown]
# ### Latent Dirichlet Allocation and Non Negative Matrix Factorization - Topic Modeling

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
import pandas as pd

# %%
#Loading datafiles
iphone7 = pd.read_csv('Amazon_Unlocked_Mobile_iphone7.csv')
iphone6 = pd.read_csv('Amazon_Unlocked_Mobile_iphone6.csv')
#iphone6S = pd.read_csv('Amazon_Unlocked_Mobile_iphone6S.csv')
#GalaxyS6Edge = pd.read_csv('Amazon_Unlocked_Mobile_SamsungGalaxy S6 Edge.csv')
#GalaxyS7Edge = pd.read_csv('Amazon_Unlocked_Mobile_SamsungGalaxy S7 Edge.csv')

# %%
# Checking for number of variables.
iphone7.shape
iphone6.shape
#iphone6S.shape
#GalaxyS6Edge.shape
#GalaxyS7Edge.shape
# Out:
# (4752, 6)

# %%
## Selecting the column containing reviews
reviews = 'Reviews'


n_samples = len(iphone7)
n_samples = len(iphone6)
#n_samples = len(iphone6S)
#n_samples = len(GalaxyS6Edge)
#n_samples = len(GalaxyS7Edge)

n_topics = 5
n_top_words = 5


def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()


data_samples = iphone7[reviews]

# %%
# Use tf-idf features for NMF.
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english',
                                   analyzer ='word',
                                   ngram_range =(2, 2))
tfidf = tfidf_vectorizer.fit_transform(data_samples)

# Fit the NMF model
nmf = NMF(n_components=n_topics, random_state=1,
          alpha=.1, l1_ratio=.5).fit(tfidf)


# Print the topics
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)
# Out:
# Topic #0:
# excellent thank ðÿ ðÿ family loves far speed far expensive
# Topic #1:
# did know android versions color gamut iphone plus know google
# Topic #2:
# best iphone iphone hands love ios apples best android marshmallow
# Topic #3:
# jet black silicon case dots appeared quality jet black finish
# Topic #4:
# ðÿ ðÿ works perfectly perfectly ðÿ time works just received

# %%
# Use tf (raw term count) features for LDA.
tf_vectorizer = CountVectorizer(max_df = 0.9,min_df = 2, stop_words='english', 
                                analyzer ='word',
                                ngram_range =(2, 2))
tf = tf_vectorizer.fit_transform(data_samples)



# Fit the LDA model
lda = LatentDirichletAllocation(n_topics=n_topics, max_iter=20,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=23)
lda.fit(tf)

# Print the topics
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Topic #0:
# great phone sim card great product phone did home button
# Topic #1:
# did know iphone plus android versions color gamut ios 10
# Topic #2:
# jet black silicon case time described arrived time ok tks
# Topic #3:
# works perfectly ios 10 best iphone ðÿ ðÿ delivered time
# Topic #4:
# excellent thank sim card brand new iphone unlocked unlocked phone
